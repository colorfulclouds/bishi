# %%
n = int(input())

pred = []


true = []

for i in range(n):
    tmp = input().split(' ')
    pred.append(float(tmp[1]))
    true.append(float(tmp[0]))
# Out:
# 10
# 1 0.9
# 0 0.7
# 1 0.6
# 1 0.55
# 0 0.52
# 1 0.4
# 0 0.38
# 0 0.35
# 1 0.31
# 0 0.1

# %%
y
# Out:
# [0.9, 0.7, 0.6, 0.55, 0.52, 0.4, 0.38, 0.35, 0.31, 0.1]

# %%
def cal():
    f = list(zip(pred , true))
    
    rank = [value2 for value1 , value2 in sorted(f , key=lambda x:x[0])]
    
    ranklist = [i+1 for i in range(len(rank)) if rank[i] == 1]
    
    posnum = 0
    negnum = 0
    
    for i in range(len(true)):
        if true[i] == 1:
            posnum = posnum+1
        else:
            negnum = negnum+1
        
    auc = 0
    auc = (sum(ranklist) - (posnum*(posnum+1))/2)/(posnum*negnum)

    return auc

# %%
cal()
# Out:
# ------------------------------------------------------------
# NameError                  Traceback (most recent call last)
# <ipython-input-8-0b9011992b43> in <module>
# ----> 1 cal()
#
# <ipython-input-7-c0133abce528> in cal()
#       1 def cal():
# ----> 2     f = list(zip(pred , true))
#       3
#       4     rank = [value2 for value1 , value2 in sorted(f , key=lambda x:x[0])]
#       5
#
# NameError: name 'pred' is not defined
