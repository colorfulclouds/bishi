# %%
arr = list(map(int , input().split(' ')))
# Out:
# 5 6 -2 1 5 -4 8 10 -22 11

# %%
dp=[0]*len(arr)

# %%
dp[0] = arr[0]

# %%
for i in range(1 , len(arr)):
    dp[i] = max(dp[i-1]+arr[i] , arr[i])

# %%
dp
# Out:
# [5, 11, 9, 10, 15, 11, 19, 29, 7, 18]
