# %%
from functools import reduce

# %%
s = input().split(' ')
# Out:
# qian fang gao neng

# %%
def reverse(x):
    return reduce(lambda x,y : x+y , list(reversed(x)))

# %%
for o in s:
    if len(o)%2 != 0:
        print(reverse(o) , end=' ')
    else:
        print(o , end=' ')
# Out:
# qian fang oag neng
