# %%
n = int(input())

mas = []

for i in range(n):
    size = int(input())
    
    ma = []
    for j in range(size):
        tmp = list(input())
        ma.append(tmp)
        
    mas.append(ma)
# Out:
# 1
# 3
# 1?1
# ?2?
# 1?1

# %%
mas[0]
# Out:
# [['1', '?', '1'], ['?', '2', '?'], ['1', '?', '1']]

# %%
def isok(arr):
    pass



res = []
def pro(arr , idx_i , idx_j):
    if idx_i == n-1 and idx_j == n-2:
        if isok(arr):
            res.append(1)
            
        return
    
    for i in range(len(arr)):
        for j in range(len(arr)):
            arr[idx_i][idx_j] = 1
            pro(arr , idx_i , idx_j)

            arr[idx_i][idx_j] = 0
            pro(arr , idx_i , idx_j)

            arr[idx_i][idx_j] = '?'

# %%
for i in range(n):
    print(mas[i])

# %%
[]
