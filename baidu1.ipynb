# %%
N = int(input())

tmp = []

for i in range(N-1):
    tmp.append(list(map(int , input().split(' '))))
# Out:
# 5
# 1 2 1
# 1 3 1
# 3 4 3
# 3 5 1

# %%
res = 0

for i in range(N-1):

    res += tmp[i][-1]

# %%
print(res // 2)
# Out:
# 6
