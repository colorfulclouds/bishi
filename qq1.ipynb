# %%
from functools import reduce

s = input().split(' ')
# Out:
# the sky is            blue!

# %%
while True:
    try:
        s.remove('')
    except ValueError:
        break

# %%
s.reverse()

# %%
res = reduce(lambda x,y: x+' '+y , s)

# %%
print(res)
# Out:
# 'blue! is sky the'
