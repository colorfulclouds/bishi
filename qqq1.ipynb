# %%
T = int(input())

arr = []

for i in range(T):
    n = int(input())
    tmp = list(map(int , input().split(' ')))
    
    arr.append(tmp)
# Out:
# 1
# 6
# 1 2 3 4 5 6

# %%
def isno(array):
    tmp = sorted(array)
    
    if tmp[0] == tmp[-1]:
        return False
    
    return True

def de(array):
    for i in range(len(array)-1):
        for j in range(i+1 , len(array)):
            i_bak = i
            j_bak = j
            if array[i] != array[j]:
                array.pop(i)
                array.pop(j)

                i = i_bak
                j = j_bak
                break
                    
    print(array)

# %%
aaa = [1,2,3,4,5,6]
de(aaa)
# Out:
# [2, 5]

# %%
aaa
# Out:
# [2, 5]

# %%
bbb = [4,4,4,3]
de(bbb)
# Out:
# ------------------------------------------------------------
# IndexError                 Traceback (most recent call last)
# <ipython-input-20-a35505118ffd> in <module>
#       1 bbb = [4,4,4,3]
# ----> 2 de(bbb)
#
# <ipython-input-17-8c677c652104> in de(array)
#      14             if array[i] != array[j]:
#      15                 array.pop(i)
# ---> 16                 array.pop(j)
#      17
#      18                 i = i_bak
#
# IndexError: pop index out of range

# %%
for i in range(T):
