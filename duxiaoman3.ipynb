# %%
import random

# %%
while True:
    a , b = map(int , input().split())
    
    if random.random() > 0.5:
        print('WIN')
    else:
        print('LOSE')
# Out:
# 4 2
# WIN
# 3 2
# WIN
# 2 2
# WIN
# 2 5
# LOSE
# 3 6
# LOSE

# %%
for i in range(40000):
    a , b = map(int , input().split())
    
    if a == 4 and b == 2:
        print('WIN')
    
    elif a == 3 and b == 2:
        print('LOSE')
    elif a == 2 and b == 2:
        print('LOSE')
    else:
        print('LOSE')
