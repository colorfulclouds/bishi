# %%
s = input()
# Out:
#  I  love     you.

# %%
s
# Out:
# ' I  love     you.'

# %%
s = s[:-1].split(' ')

# %%
res = ''

for i in range(len(s)-1 , -1 , -1):
    if len(s[i]) != 0:
        res = res+s[i]+' '

# %%
print(res[:-1]+'.')
# Out:
# you love I.
