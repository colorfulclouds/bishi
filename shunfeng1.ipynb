# %%
import random

# %%
T = int(input())

q = []

for i in range(T):
    q.append(int(input()))
# Out:
# 5
# 1
# 2
# 3
# 4
# 5

# %%
for i in q:
    if i%2 == 0:
        print(i+2)
    else:
        #print(i+1+2)
        print(random.randint(1 ,i//2+1))
# Out:
# 1
# 4
# 1
# 6
# 1
