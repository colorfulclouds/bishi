# %%
s = input()
# Out:
# lll

# %%
flag = 1

for i in range(len(s)-1):
    res = s[i]
    flag = 1
    for j in range(i+1 , len(s)):
        if s[i] == s[j]:
            flag = 0
            break
            
    
if flag == 1:
    print(res)
else:
    print('#')
# Out:
# #
