# %%
n = int(input())

num = list(map(int , input().split(' ')))
# Out:
# 6
# 1 2 3 4 5 6

# %%
num = sorted(num)

# %%
num
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
if n%2 == 1:
    print(num[n//2])
else:
    print(num[n//2 - 1])
# Out:
# 3
