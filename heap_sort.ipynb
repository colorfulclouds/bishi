# %%
import heapq

# %%
heap = [3,4,2,5,4,3,12,10,9,8]

heapq.heapify(heap)

# %%
heap
# Out:
# [2, 4, 3, 5, 4, 3, 12, 10, 9, 8]

# %%
heapq.heappush(heap , 22)

# %%
heap
# Out:
# [2, 4, 3, 5, 4, 3, 12, 10, 9, 8, 22]

# %%
heapq.heapify(heap)

# %%
heap
# Out:
# [2, 4, 3, 5, 4, 3, 12, 10, 9, 8, 22]

# %%
heapq.heappush(heap , 7)

# %%
heapq.heapify(heap)

# %%
heap
# Out:
# [2, 4, 3, 5, 4, 3, 12, 10, 9, 8, 22, 7]
