# %%
n = int(input())

exp_s = input()
# Out:
# 6
# 3 + 2 + 1 + -4 * -5 + 1

# %%
exp = ''

for i in range(len(exp_s)):
    if exp_s[i] != ' ':
        exp = exp+exp_s[i]

# %%
exp
# Out:
# '3+2+1+-4*-5+1'

# %%
res = exp.split('+')
print(res)
# Out:
# ['3', '2', '1', '-4*-5', '1']

# %%
for r in res:

# %%
import stack
# Out:
# ------------------------------------------------------------
# ModuleNotFoundError        Traceback (most recent call last)
# <ipython-input-13-2c5f192efb44> in <module>
# ----> 1 import stack
#
# ModuleNotFoundError: No module named 'stack'
